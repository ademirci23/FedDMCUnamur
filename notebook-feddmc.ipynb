# %%
# !git clone -b dev https://github.com/ademirci23/FedDMCUnamur.git
# %cd /kaggle/working/FedDMCUnamur
# !pip install -r requirements.txt
# Out:
# Cloning into 'FedDMCUnamur'...
# fatal: unable to access 'https://github.com/ademirci23/FedDMCUnamur.git/': Could not resolve host: github.com
# [Errno 2] No such file or directory: '/kaggle/working/FedDMCUnamur'
# /kaggle/working
# ERROR: Could not open requirements file: [Errno 2] No such file or directory: 'requirements.txt'

# %%
# !python main.py --dataset mnist --byz_type Scaling_attack --agg_type pca_hdbscan_b \
  --epoch 1 --beta 5 --num_of_clients 100 --num_malicious_client 28 \
  --learning_rate 0.01 --pca_d 10
# Out:
# python3: can't open file '/kaggle/working/main.py': [Errno 2] No such file or directory
